# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline

from newsapi import NewsApiClient
load_dotenv()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/maurolp15/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Read your api key environment variable
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news = newsapi.get_everything(
    q="Bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy")

# Print total articles
print(f"Total articles about Bitcoin: {bitcoin_news['totalResults']}")
print('-----------------------------------')

# Show sample article
(bitcoin_news["articles"][0])
# Out:
# Total articles about Bitcoin: 6890
# -----------------------------------
# {'source': {'id': None, 'name': 'New York Times'},
#  'author': 'Katie Benner',
#  'title': 'Justice Dept. Announces Raft of Changes Meant to Deter Cyberthreats',
#  'description': 'The moves came a week after the department made its largest financial seizure ever, confiscating over $3.6 billion worth of Bitcoin stolen in a 2016 hacking.',
#  'url': 'https://www.nytimes.com/2022/02/17/us/politics/justice-department-cybersecurity.html',
#  'urlToImage': 'https://static01.nyt.com/images/2022/02/17/us/politics/17dc-justice/merlin_199612353_b05bfb07-3da8-404e-8a75-221181e5d014-facebookJumbo.jpg',
#  'publishedAt': '2022-02-17T23:51:49Z',
#  'content': 'Even in cyberspace, the Department of Justice is able to use a tried and true investigative technique, following the money, Ms. Monaco said. Its what led us to Al Capone in the 30s. It helped us dest… [+1176 chars]'}

# %%
# Fetch the Ethereum news articles
ethereum_news = newsapi.get_everything(
    q="Ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy")

# Print total articles
print(f"Total articles about Ethereum: {ethereum_news['totalResults']}")
print('-----------------------------------')

# Show sample article
ethereum_news["articles"][0]
# Out:
# Total articles about Ethereum: 2856
# -----------------------------------
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Shanti Escalante-De Mattei',
#  'title': 'Web3 Threatens to Segregate Our Online Lives',
#  'description': 'Governance tokens seem like a tantalizing solution to content moderation struggles. They only give the appearance of democracy.',
#  'url': 'https://www.wired.com/story/web3-governance-tokens-cryptocurrency-content-moderation/',
#  'urlToImage': 'https://media.wired.com/photos/621d66c7ea3b8f283853aa29/191:100/w_1280,c_limit/Web3-Threatens-to-Segregate-Our-Online-Lives.jpg',
#  'publishedAt': '2022-03-01T14:00:00Z',
#  'content': 'In February, shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at Ethereum Name Service (ENS), a web3 business, had written the following in May 201… [+3096 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_news["articles"]:
    try:
        title = article["title"]
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "Title": title,
            "Text": text,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu})
        
    except AttributeError:
        pass
    
bitcoin_df = pd.DataFrame(bitcoin_sentiments)
columns = ["Title", "Text", "Compound", "Positive", "Negative", "Neutral"]
bitcoin_df = bitcoin_df[columns]

bitcoin_df.head()
# Out:
#                                                Title  \
# 0  Justice Dept. Announces Raft of Changes Meant ...
# 1  Inside Heather Morgan and Ilya Lichtenstein's ...
# 2  Super Bowl Crypto Ads Feature Larry David, LeB...
# 3  It Only Took 3 Days for Netflix to Order a Doc...
# 4  Ilya Lichtenstein Held in Bitcoin Case While H...
#
#                                                 Text  Compound  Positive  \
# 0  Even in cyberspace, the Department of Justice ...    0.7351     0.147
# 1  The couple would never flee from the country a...   -0.3400     0.057
# 2  If Sundays Super Bowl ads are any indication, ...    0.7783     0.163
# 3  The news of one of the biggest money launderin...    0.5859     0.124
# 4  The confiscation of the Bitcoin that remained ...    0.6486     0.146
#
#    Negative  Neutral
# 0     0.000    0.853
# 1     0.118    0.825
# 2     0.000    0.837
# 3     0.000    0.876
# 4     0.000    0.854

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_news["articles"]:
    try:
        title = article["title"]
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "Title": title,
            "Text": text,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu})
        
    except AttributeError:
        pass
    
ethereum_df = pd.DataFrame(ethereum_sentiments)
columns = ["Title", "Text", "Compound", "Positive", "Negative", "Neutral"]
ethereum_df = ethereum_df[columns]

ethereum_df.head()
# Out:
#                                                Title  \
# 0       Web3 Threatens to Segregate Our Online Lives
# 1  The Market Has Spoken, and It Says Ethereum Is...
# 2  Colorado will accept crypto for payment of sta...
# 3  Coinbase earnings show trading of ethereum and...
# 4   How Ukrainians are fundraising in cryptocurrency
#
#                                                 Text  Compound  Positive  \
# 0  In February, shit hit the fan in the usual way...   -0.3182     0.059
# 1  Technical analysis isnt a perfect tool, but it...   -0.2498     0.000
# 2  People in Colorado will be able to pay their s...   -0.1027     0.000
# 3  Coinbase reported that the share of trading vo...    0.6705     0.188
# 4  Illustration by James Bareham / The Verge\r\n\...   -0.4588     0.000
#
#    Negative  Neutral
# 0     0.093    0.848
# 1     0.059    0.941
# 2     0.036    0.964
# 3     0.000    0.812
# 4     0.083    0.917

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          Compound    Positive    Negative     Neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.042606    0.071480    0.056850    0.871680
# std      0.475269    0.070815    0.070677    0.086704
# min     -0.895700    0.000000    0.000000    0.627000
# 25%     -0.284450    0.000000    0.000000    0.824500
# 50%      0.000000    0.058000    0.031500    0.874500
# 75%      0.451975    0.105750    0.091250    0.938250
# max      0.910000    0.301000    0.269000    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#          Compound    Positive    Negative     Neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.171198    0.084930    0.044130    0.870950
# std      0.447205    0.069879    0.064569    0.084197
# min     -0.913600    0.000000    0.000000    0.627000
# 25%     -0.012900    0.034750    0.000000    0.830250
# 50%      0.202300    0.072500    0.000000    0.875000
# 75%      0.514625    0.126750    0.067750    0.927250
# max      0.918600    0.290000    0.312000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum has the highest mean positive score with 0.084
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum has the highest compound score with 0.918
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin has the highest positive score with 0.301

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

nltk.download('stopwords')
nltk.download('reuters')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/maurolp15/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package reuters to
# [nltk_data]     /Users/maurolp15/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/maurolp15/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addons = {'bitcoin', 'btc', 'ethereum', 'eth'}

# %%
sw = set(stopwords.words('english'))
regex = re.compile("[^a-zA-Z ]")
re_clean = regex.sub('', text)
words = word_tokenize(re_clean)
lem = [lemmatizer.lemmatize(word) for word in words]
tokens = [word.lower() for word in lem if word.lower() not in sw]
tokens
# Out:
# ['polkadot',
#  'dot',
#  'blockchain',
#  'network',
#  'dot',
#  'token',
#  'hold',
#  'impressive',
#  'position',
#  'cryptocurrency',
#  'market',
#  'today',
#  'dot',
#  'twelfthlargest',
#  'cryptocurrency',
#  'market',
#  'cap',
#  'number',
#  'char']

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    
    # Remove the stop words
    sw = set(stopwords.words('english'))

    # Convert the words to lowercase
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
texts = []
for t in bitcoin_sentiments:
    text = t['Text']
    texts.append(text)

tokens = []
for t in texts:
    tokens.append(tokenizer(t))
    
bitcoin_df['Tokens'] = tokens

bitcoin_df.head()
# Out:
#                                                Title  \
# 0  Justice Dept. Announces Raft of Changes Meant ...
# 1  Inside Heather Morgan and Ilya Lichtenstein's ...
# 2  Super Bowl Crypto Ads Feature Larry David, LeB...
# 3  It Only Took 3 Days for Netflix to Order a Doc...
# 4  Ilya Lichtenstein Held in Bitcoin Case While H...
#
#                                                 Text  Compound  Positive  \
# 0  Even in cyberspace, the Department of Justice ...    0.7351     0.147
# 1  The couple would never flee from the country a...   -0.3400     0.057
# 2  If Sundays Super Bowl ads are any indication, ...    0.7783     0.163
# 3  The news of one of the biggest money launderin...    0.5859     0.124
# 4  The confiscation of the Bitcoin that remained ...    0.6486     0.146
#
#    Negative  Neutral                                             Tokens
# 0     0.000    0.853  [even, cyberspace, department, justice, able, ...
# ...

# %%
# Create a new tokens column for Ethereum
texts = []
for t in ethereum_sentiments:
    text = t['Text']
    texts.append(text)

tokens = []
for t in texts:
    tokens.append(tokenizer(t))
    
ethereum_df['Tokens'] = tokens

ethereum_df.head()
# Out:
#                                                Title  \
# 0       Web3 Threatens to Segregate Our Online Lives
# 1  The Market Has Spoken, and It Says Ethereum Is...
# 2  Colorado will accept crypto for payment of sta...
# 3  Coinbase earnings show trading of ethereum and...
# 4   How Ukrainians are fundraising in cryptocurrency
#
#                                                 Text  Compound  Positive  \
# 0  In February, shit hit the fan in the usual way...   -0.3182     0.059
# 1  Technical analysis isnt a perfect tool, but it...   -0.2498     0.000
# 2  People in Colorado will be able to pay their s...   -0.1027     0.000
# 3  Coinbase reported that the share of trading vo...    0.6705     0.188
# 4  Illustration by James Bareham / The Verge\r\n\...   -0.4588     0.000
#
#    Negative  Neutral                                             Tokens
# 0     0.093    0.848  [february, shit, hit, fan, usual, way, old, tw...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
bitcoin_text = ' '.join(bitcoin_df.Text)
bitcoin_processed = tokenizer(bitcoin_text)
bitcoin_ngrams = Counter(ngrams(bitcoin_processed, n=2))
bitcoin_ngrams.most_common(10)
# Out:
# [(('feb', 'reuters'), 12),
#  (('march', 'reuters'), 8),
#  (('char', 'feb'), 6),
#  (('char', 'bitcoin'), 5),
#  (('new', 'york'), 5),
#  (('char', 'london'), 5),
#  (('invasion', 'ukraine'), 4),
#  (('since', 'russia'), 4),
#  (('char', 'new'), 4),
#  (('london', 'feb'), 4)]

# %%
# Generate the Ethereum N-grams where N=2
ethereum_text = ' '.join(ethereum_df.Text)
ethereum_processed = tokenizer(ethereum_text)
ethereum_ngrams = Counter(ngrams(ethereum_processed, n=2))
ethereum_ngrams.most_common(10)
# Out:
# [(('char', 'cryptocurrency'), 4),
#  (('cb', 'insights'), 4),
#  (('insights', 'newsletter'), 4),
#  (('newsletter', 'subscriber'), 4),
#  (('subscriber', 'get'), 4),
#  (('get', 'free'), 4),
#  (('free', 'newsletter'), 4),
#  (('newsletter', 'stay'), 4),
#  (('stay', 'step'), 4),
#  (('step', 'ahead'), 4)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(10)

# %%
# Use token_count to get the top 10 words for Bitcoin
bitcoin_top_10 = token_count(bitcoin_processed)
bitcoin_top_10
# Out:
# [('char', 100),
#  ('bitcoin', 35),
#  ('ha', 24),
#  ('reuters', 22),
#  ('crypto', 18),
#  ('cryptocurrency', 18),
#  ('feb', 16),
#  ('us', 16),
#  ('ukraine', 13),
#  ('cryptocurrencies', 13)]

# %%
# Use token_count to get the top 10 words for Ethereum
ethereum_top_10 = token_count(ethereum_processed)
ethereum_top_10
# Out:
# [('char', 96),
#  ('ha', 23),
#  ('cryptocurrency', 18),
#  ('market', 17),
#  ('crypto', 16),
#  ('ethereum', 15),
#  ('cryptocurrencies', 15),
#  ('year', 13),
#  ('digital', 13),
#  ('ukraine', 13)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
terms_list = str(bitcoin_df["Tokens"].tolist())

wordcloud = WordCloud(colormap="RdYlBu").generate(terms_list)
plt.imshow(wordcloud)
plt.axis("off")
fontdict = {"fontsize": 20, "fontweight": "bold"}
plt.title("Bitcoin Word Cloud", fontdict=fontdict)
plt.show()

# %%
# Generate the Ethereum word cloud
terms_list = str(ethereum_df["Tokens"].tolist())

wordcloud = WordCloud(colormap="RdYlBu").generate(terms_list)
plt.imshow(wordcloud)
plt.axis("off")
fontdict = {"fontsize": 20, "fontweight": "bold"}
plt.title("Ethereum Word Cloud", fontdict=fontdict)
plt.show()

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 13.9 MB 2.2 MB/s eta 0:00:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
concat_bitcoin = bitcoin_df['Text'].str.cat(sep=', ')

# %%
# Run the NER processor on all of the text
bitcoin_ner = nlp(concat_bitcoin)

# Add a title to the document
bitcoin_ner.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Even in cyberspace,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Department of Justice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is able to use a tried and true investigative technique, following the money, Ms.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monaco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. Its what led us to
# ...

# %%
# List all Entities
for ent in bitcoin_ner.ents:
    print(ent.text)
# Out:
# the Department of Justice
# Monaco
# Al Capone
# Margaret Lynaugh
# Sundays Super Bowl
# Larry David
# LeBron James
# +3454
# one
# Tuesday
# $4.5 billion
# Lichtensteins
# Feb. 1
# roughly $3.6 billion
# the New York Times
# Feb 22
# Reuters
# 2021
# thousands
# March 1
# Reuters
# Russia
# Ukraine
# Satoshi Nakamoto
# 2008
# Getty
# Welcome to
# Nonfungible Tidbits
# this week
# Russia
# Ukraine
# Ukrainians
# Russian
# YouTube
# Alex Castro
# Verge
# BitConnect
# Nurphoto/Getty
# Russia
# last Thursday
# Ukranian
# Mexico City
# Telegr
# Feb 15
# Reuters
# Europe
# two
# Russia
# LONDON
# March 4
# Reuters
# Russia
# Ukraine
# Russia
# Reuters
# BITCOIN
# Ukrainian
# Tom Lee
# Ukraine
# Summary</li><li>
# Law firms</li><li>
#
# documents</li></ul
# Shark Tank
# Kevin O'Leary's
# 100,000
# 200,000
# 300,000
# two-week
# Tuesday
# Russians
# Ukrainians
# SAN SALVADOR
# Feb 20
# Reuters
# El Salvador
# Nayib Bukele
# Sunday
# Congress
# Central American
# the past 12 years
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
concat_ethereum = ethereum_df['Text'].str.cat(sep=', ')

# %%
# Run the NER processor on all of the text
ethereum_ner = nlp(concat_ethereum)

# Add a title to the document
ethereum_ner.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(ethereum_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Name Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# ...

# %%
# List all Entities
for ent in ethereum_ner.ents:
    print(ent.text)
# Out:
# February
# Ethereum Name Service
# ENS
# May 201
# Ethereum
# ETH-USD
# Crypto
# Colorado
# the middle of this year
# US
# Jared Polis
# Coinbase
# last year
# Between 2020 and 2021
# James Bareham
# More than $15 million
# More than $15 million
# Ukrainian
# Russia
# 2022
# Facebook
# Microsoft
# Last night
# Twitter
# Ethereum
# second
# two months
# NFT
# two hours
# YouTube
# Waka Flacka Fla
# the past few years
# NFT
# $23 billion
# TIME
# weekly
# TIME
# weekly
# Joe Biden
# Wednesday
# first
# Bitcoin
# Brett Harrison
# Bitcoin
# the past few years
# NFT
# $23 billion
# Ethereum
# American Express
# Kitco News
# Russia
# Ukraine
# Opera
# Keshas
# Opera
# Monday
# American Express
# Ukrainian
# more than $4 million
# Russia
# Elliptic
# Ukraine
# Russia
# Elliptic
# nearly $55 million
# Bitcoin, Ethereum
# DogeCoin
# Binance
# June 28, 2021
# REUTERS
# Dado Ruvic/Illus
# only one
# NFT
# Chatroom
# Discord
# Wiki
# FAQs
# Ukraine
# Kyiv
# Mykhailo Fedoro
# MetaMask
# Infura
# ...

# %% [markdown]
# ---
